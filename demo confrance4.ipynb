# %% [markdown]
# # محرك بحث مترجم من لغة الي اخري
# ## المقدمة:
# ### يستخدم محرك البحث التحليل الدلالي للتحسين نتائج البحث واسترجاع المعلومات للموضوعات ذات العلاقة بالكلمات البحثية
# ## الخطوات
# استقبال الكلمة المراد البحث عنها من المستخدم
# ايجاد الكلمات المرادفة لها من المعاجم اللغوية كالوردنت او ايجادها من تحليل الكلمات ذات العلاقة باستخدام
# word2vecلموسوعة ويكي بديا عربي (بافتراض انالكلمةالمراد البحث عنها  باللغة العربية)
# البحث عن الكلمة الاصلية
# ومرادفاتها في الويكي بديا واسترجاع الوثائق المطروحةمن قبل الويكي بديا
# ترشيح الوثائق المسترجعة من الويكي بديا باستخدام تحليل دلالي مقترح
# عرض النتائج علي المستخدم

# %% [markdown]
# ## الاعدادات
# ايجاد كلمات ومرادفاتها من موسوعة لغة عربيه علي الويكي بديا عن طريق
# Word2vec

# %% [markdown]
# # Arabic Wrod2vec:
#
# تنفيذ Word2Vec لمحتوي ويكي بديا باللغة العربية

# %%
##http://textminingonline.com/getting-started-with-word2vec-and-glove-in-python
from gensim.models import word2vec

ar_sentences = word2vec.Text8Corpus('arwiki-20171201-pages-articles-multistream-index.txt')
 
ar_model = word2vec.Word2Vec(ar_sentences, size=200)
ar_model.save('ar_outout.txt')

# %%
## عرض الكلمات كلها في الموسوعه التي تم التدريب عليها للحصول علي علاقات ترادف بينها وبين بعض 
ar_model.wv.vocab
# Out:
# {'to': <gensim.models.keyedvectors.Vocab at 0x7f613da55278>,
#  'edit': <gensim.models.keyedvectors.Vocab at 0x7f6140c60438>,
#  'Arabic': <gensim.models.keyedvectors.Vocab at 0x7f6140c60898>,
#  'pages': <gensim.models.keyedvectors.Vocab at 0x7f6140c60cc0>,
#  'العربي': <gensim.models.keyedvectors.Vocab at 0x7f6140c60f28>,
#  'الرئيسية': <gensim.models.keyedvectors.Vocab at 0x7f613db37da0>,
#  'أخطاء': <gensim.models.keyedvectors.Vocab at 0x7f613db373c8>,
#  'وطلب': <gensim.models.keyedvectors.Vocab at 0x7f613db372e8>,
#  'الصفحات': <gensim.models.keyedvectors.Vocab at 0x7f613da2e390>,
#  'التغييرات': <gensim.models.keyedvectors.Vocab at 0x7f613da2eb00>,
#  'الجارية': <gensim.models.keyedvectors.Vocab at 0x7f613dba9668>,
#  '(أدب)': <gensim.models.keyedvectors.Vocab at 0x7f613dba9828>,
#  'مكتبة': <gensim.models.keyedvectors.Vocab at 0x7f613dba1f60>,
#  'الكونغرس': <gensim.models.keyedvectors.Vocab at 0x7f613db9abe0>,
#  '(تكساس)': <gensim.models.keyedvectors.Vocab at 0x7f613db9ac50>,
#  'Page': <gensim.models.keyedvectors.Vocab at 0x7f613da366a0>,
#  '(مدينة)': <gensim.models.keyedvectors.Vocab at 0x7f613d9ef048>,
#  'خلدون': <gensim.models.keyedvectors.Vocab at 0x7f613dba6278>,
#  'الأردنية': <gensim.models.keyedvectors.Vocab at 0x7f613dba66a0>,
#  'الهاشمية': <gensim.models.keyedvectors.Vocab at 0x7f613dba6fd0>,
#  'مفتوح': <gensim.models.keyedvectors.Vocab at 0x7f613de27860>,
#  'المصدر': <gensim.models.keyedvectors.Vocab at 0x7f613dba3080>,
#  'جنو': <gensim.models.keyedvectors.Vocab at 0x7f613dba3710>,
#  'للوثائق': <gensim.models.keyedvectors.Vocab at 0x7f613dba3748>,
#  'الحرة': <gensim.models.keyedvectors.Vocab at 0x7f613dba3898>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f6140bf5e48>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7f613db9f320>,
#  'page': <gensim.models.keyedvectors.Vocab at 0x7f613dc51668>,
#  'عام': <gensim.models.keyedvectors.Vocab at 0x7f613dc51048>,
#  'تشغيل': <gensim.models.keyedvectors.Vocab at 0x7f613dc5fb70>,
#  'الحاسبات': <gensim.models.keyedvectors.Vocab at 0x7f613da3d7f0>,
#  'برمجيات': <gensim.models.keyedvectors.Vocab at 0x7f613ddad9b0>,
#  '(توضيح)': <gensim.models.keyedvectors.Vocab at 0x7f613ddad908>,
#  'حرة': <gensim.models.keyedvectors.Vocab at 0x7f6140b78668>,
#  'مقترحة': <gensim.models.keyedvectors.Vocab at 0x7f6140bd6f28>,
#  'المفتوح': <gensim.models.keyedvectors.Vocab at 0x7f6140bf8320>,
#  'الدول': <gensim.models.keyedvectors.Vocab at 0x7f6140bf8438>,
#  'العربية': <gensim.models.keyedvectors.Vocab at 0x7f6140bf8748>,
#  'المقالات': <gensim.models.keyedvectors.Vocab at 0x7f6140bf8898>,
#  'مقالة': <gensim.models.keyedvectors.Vocab at 0x7f6140bf89b0>,
#  'بن': <gensim.models.keyedvectors.Vocab at 0x7f6140bf8a58>,
#  'موسى': <gensim.models.keyedvectors.Vocab at 0x7f6140bf8b00>,
#  'الخوارزمي': <gensim.models.keyedvectors.Vocab at 0x7f6140bf8b70>,
#  'البذرة': <gensim.models.keyedvectors.Vocab at 0x7f6140bf8d30>,
#  'تحتاج': <gensim.models.keyedvectors.Vocab at 0x7f6140bf8d68>,
#  'الأبيض': <gensim.models.keyedvectors.Vocab at 0x7f6140bf8dd8>,
#  'المتوسط': <gensim.models.keyedvectors.Vocab at 0x7f6140bf8ef0>,
#  'اوروبي': <gensim.models.keyedvectors.Vocab at 0x7f6140bf8668>,
#  'عمان': <gensim.models.keyedvectors.Vocab at 0x7f6140c63c18>,
#  'التأليف': <gensim.models.keyedvectors.Vocab at 0x7f6140c63668>,
#  'والنشر': <gensim.models.keyedvectors.Vocab at 0x7f61368b3080>,
#  'سعيد': <gensim.models.keyedvectors.Vocab at 0x7f61368b30f0>,
#  'في': <gensim.models.keyedvectors.Vocab at 0x7f61368b3160>,
#  'الإسلام': <gensim.models.keyedvectors.Vocab at 0x7f61368b3198>,
#  'الروسي': <gensim.models.keyedvectors.Vocab at 0x7f61368b3240>,
#  'لادن': <gensim.models.keyedvectors.Vocab at 0x7f61368b33c8>,
#  'سبتمبر': <gensim.models.keyedvectors.Vocab at 0x7f61368b3400>,
#  'امريكية': <gensim.models.keyedvectors.Vocab at 0x7f61368b35c0>,
#  'متحدة': <gensim.models.keyedvectors.Vocab at 0x7f61368b3668>,
#  'أوسط': <gensim.models.keyedvectors.Vocab at 0x7f61368b36d8>,
#  'غيتس': <gensim.models.keyedvectors.Vocab at 0x7f61368b3710>,
#  'الأمريكية': <gensim.models.keyedvectors.Vocab at 0x7f61368b3748>,
#  'المتحدة': <gensim.models.keyedvectors.Vocab at 0x7f61368b3940>,
#  'بي': <gensim.models.keyedvectors.Vocab at 0x7f61368b3978>,
#  'سي': <gensim.models.keyedvectors.Vocab at 0x7f61368b39b0>,
#  'القاعدة': <gensim.models.keyedvectors.Vocab at 0x7f61368b3a20>,
#  'سلطان': <gensim.models.keyedvectors.Vocab at 0x7f61368b3b70>,
#  'آل': <gensim.models.keyedvectors.Vocab at 0x7f61368b3be0>,
#  'نهيان': <gensim.models.keyedvectors.Vocab at 0x7f61368b3c88>,
#  'الدجاج': <gensim.models.keyedvectors.Vocab at 0x7f61368b3cf8>,
#  'خليفة': <gensim.models.keyedvectors.Vocab at 0x7f61368b3ef0>,
#  'الدين': <gensim.models.keyedvectors.Vocab at 0x7f61368b3f60>,
#  'زيدان': <gensim.models.keyedvectors.Vocab at 0x7f61368b3fd0>,
#  'لغة': <gensim.models.keyedvectors.Vocab at 0x7f61368b3470>,
#  'محفوظ': <gensim.models.keyedvectors.Vocab at 0x7f6140c6a208>,
#  '2004': <gensim.models.keyedvectors.Vocab at 0x7f613dc5c7f0>,
#  'الألمانية': <gensim.models.keyedvectors.Vocab at 0x7f613dc5c908>,
#  'الديمقراطية': <gensim.models.keyedvectors.Vocab at 0x7f613de7a518>,
#  'برلين': <gensim.models.keyedvectors.Vocab at 0x7f613664a080>,
#  'الفيل': <gensim.models.keyedvectors.Vocab at 0x7f613664a198>,
#  'شاهين': <gensim.models.keyedvectors.Vocab at 0x7f613664a2e8>,
#  'مريم': <gensim.models.keyedvectors.Vocab at 0x7f613664a358>,
#  'تجريبي': <gensim.models.keyedvectors.Vocab at 0x7f613664a390>,
#  'سامية': <gensim.models.keyedvectors.Vocab at 0x7f613664a400>,
#  'متكررة': <gensim.models.keyedvectors.Vocab at 0x7f613664a4a8>,
#  'بالقادمين': <gensim.models.keyedvectors.Vocab at 0x7f613664a4e0>,
#  'الجدد': <gensim.models.keyedvectors.Vocab at 0x7f613664a6d8>,
#  'صفحات': <gensim.models.keyedvectors.Vocab at 0x7f613664a748>,
#  'النقاش': <gensim.models.keyedvectors.Vocab at 0x7f613664a780>,
#  'إدارة': <gensim.models.keyedvectors.Vocab at 0x7f613664a7b8>,
#  'المحتوى': <gensim.models.keyedvectors.Vocab at 0x7f613664a7f0>,
#  'المجتمع': <gensim.models.keyedvectors.Vocab at 0x7f613664a828>,
#  'إنترنت': <gensim.models.keyedvectors.Vocab at 0x7f613664a860>,
#  'و': <gensim.models.keyedvectors.Vocab at 0x7f613664a898>,
#  'تعليمات': <gensim.models.keyedvectors.Vocab at 0x7f613664ac88>,
#  'فرناس': <gensim.models.keyedvectors.Vocab at 0x7f613664ad68>,
#  'نصر': <gensim.models.keyedvectors.Vocab at 0x7f613664ada0>,
#  'محمد': <gensim.models.keyedvectors.Vocab at 0x7f613664add8>,
#  'الفارابي': <gensim.models.keyedvectors.Vocab at 0x7f613664ae48>,
#  'الحذف': <gensim.models.keyedvectors.Vocab at 0x7f613664ae80>,
#  'الحالية': <gensim.models.keyedvectors.Vocab at 0x7f613664aeb8>,
#  'الاوسط': <gensim.models.keyedvectors.Vocab at 0x7f613664aef0>,
#  '(مغنية)': <gensim.models.keyedvectors.Vocab at 0x7f613664af60>,
#  'أينشتاين': <gensim.models.keyedvectors.Vocab at 0x7f613664af98>,
#  'مثلثي': <gensim.models.keyedvectors.Vocab at 0x7f613664afd0>,
#  'وهبي': <gensim.models.keyedvectors.Vocab at 0x7f613664a3c8>,
#  'التل': <gensim.models.keyedvectors.Vocab at 0x7f613664a710>,
#  'المنورة': <gensim.models.keyedvectors.Vocab at 0x7f613dd0aef0>,
#  'أكدية': <gensim.models.keyedvectors.Vocab at 0x7f613dd0afd0>,
#  'عربي': <gensim.models.keyedvectors.Vocab at 0x7f613dcf2b00>,
#  'الحسيني': <gensim.models.keyedvectors.Vocab at 0x7f613dcf2550>,
#  'الفلك': <gensim.models.keyedvectors.Vocab at 0x7f613dcf25c0>,
#  'أفريقية': <gensim.models.keyedvectors.Vocab at 0x7f613dbbc668>,
#  'آسيوية': <gensim.models.keyedvectors.Vocab at 0x7f613dbbc9e8>,
#  'العتيبي': <gensim.models.keyedvectors.Vocab at 0x7f613dbbca20>,
#  'قباني': <gensim.models.keyedvectors.Vocab at 0x7f613dbc0cc0>,
#  'الإمارات': <gensim.models.keyedvectors.Vocab at 0x7f613dbc0438>,
#  'تطوير': <gensim.models.keyedvectors.Vocab at 0x7f613dbc0d68>,
#  'البرمجيات': <gensim.models.keyedvectors.Vocab at 0x7f613dbc0e80>,
#  'وزو': <gensim.models.keyedvectors.Vocab at 0x7f613dbc0e10>,
#  'الجزائر': <gensim.models.keyedvectors.Vocab at 0x7f6140bfb9b0>,
#  'افريقيا': <gensim.models.keyedvectors.Vocab at 0x7f6140bfb9e8>,
#  'الولايات': <gensim.models.keyedvectors.Vocab at 0x7f6140bfba20>,
#  'لغات': <gensim.models.keyedvectors.Vocab at 0x7f6140bfb048>,
#  '(لغة)': <gensim.models.keyedvectors.Vocab at 0x7f6140bfb080>,
#  'اصطناعية': <gensim.models.keyedvectors.Vocab at 0x7f6140bfb160>,
#  'أعلام': <gensim.models.keyedvectors.Vocab at 0x7f6140bfb240>,
#  'الجزائريين': <gensim.models.keyedvectors.Vocab at 0x7f6140bfb940>,
#  'يورك': <gensim.models.keyedvectors.Vocab at 0x7f6140bfb320>,
#  'الشريف': <gensim.models.keyedvectors.Vocab at 0x7f6140bfbb00>,
#  'ذي': <gensim.models.keyedvectors.Vocab at 0x7f6140bfbb38>,
#  'قار': <gensim.models.keyedvectors.Vocab at 0x7f6140bfbb70>,
#  'أمازيغية': <gensim.models.keyedvectors.Vocab at 0x7f6140bfbbe0>,
#  'العاصمة': <gensim.models.keyedvectors.Vocab at 0x7f6140bfbda0>,
#  'قطر': <gensim.models.keyedvectors.Vocab at 0x7f6140bfbf60>,
#  'الوطني': <gensim.models.keyedvectors.Vocab at 0x7f6140bfb4e0>,
#  'رؤساء': <gensim.models.keyedvectors.Vocab at 0x7f6140bfb6d8>,
#  'يهوه': <gensim.models.keyedvectors.Vocab at 0x7f6140bfb710>,
#  'القمر': <gensim.models.keyedvectors.Vocab at 0x7f6140bfbcf8>,
#  'الشمسية': <gensim.models.keyedvectors.Vocab at 0x7f6140bfb6a0>,
#  'مقدسة': <gensim.models.keyedvectors.Vocab at 0x7f6140b900b8>,
#  'آري': <gensim.models.keyedvectors.Vocab at 0x7f6140b900f0>,
#  'موريتانيا': <gensim.models.keyedvectors.Vocab at 0x7f6140b90160>,
#  'ذو': <gensim.models.keyedvectors.Vocab at 0x7f6140b90198>,
#  'النجوم': <gensim.models.keyedvectors.Vocab at 0x7f6140b902e8>,
#  'يس': <gensim.models.keyedvectors.Vocab at 0x7f6140b90390>,
#  'خان': <gensim.models.keyedvectors.Vocab at 0x7f6140b90400>,
#  'الأنباط': <gensim.models.keyedvectors.Vocab at 0x7f6140b90438>,
#  'حماس': <gensim.models.keyedvectors.Vocab at 0x7f6140b90470>,
#  'ياسين': <gensim.models.keyedvectors.Vocab at 0x7f6140b904a8>,
#  'حيان': <gensim.models.keyedvectors.Vocab at 0x7f6140b90518>,
#  'برمجة': <gensim.models.keyedvectors.Vocab at 0x7f6140b905c0>,
#  'الحاسوب': <gensim.models.keyedvectors.Vocab at 0x7f6140b90668>,
#  'آسيا': <gensim.models.keyedvectors.Vocab at 0x7f6140b90748>,
#  'شمسي': <gensim.models.keyedvectors.Vocab at 0x7f6140b907f0>,
#  'الهيثم': <gensim.models.keyedvectors.Vocab at 0x7f6140b90828>,
#  'البرمجة': <gensim.models.keyedvectors.Vocab at 0x7f6140b90550>,
#  'المسلمون': <gensim.models.keyedvectors.Vocab at 0x7f6140b90908>,
#  'مسلمين': <gensim.models.keyedvectors.Vocab at 0x7f6140b90940>,
#  '(منظمة': <gensim.models.keyedvectors.Vocab at 0x7f6140b90978>,
#  'عسكرية)': <gensim.models.keyedvectors.Vocab at 0x7f6140b909b0>,
#  'الله)': <gensim.models.keyedvectors.Vocab at 0x7f6140b90a20>,
#  'تقسيم': <gensim.models.keyedvectors.Vocab at 0x7f6140b90a90>,
#  'فلسطين': <gensim.models.keyedvectors.Vocab at 0x7f6140b90ac8>,
#  'مشعل': <gensim.models.keyedvectors.Vocab at 0x7f6140b90b00>,
#  'العالمية': <gensim.models.keyedvectors.Vocab at 0x7f6140b905f8>,
#  'الثانية': <gensim.models.keyedvectors.Vocab at 0x7f6140b90b38>,
#  'بلادي': <gensim.models.keyedvectors.Vocab at 0x7f6140b90b70>,
#  '(أحياء)': <gensim.models.keyedvectors.Vocab at 0x7f6140b90ba8>,
#  'النمسا': <gensim.models.keyedvectors.Vocab at 0x7f6140b90c18>,
#  'السياسي': <gensim.models.keyedvectors.Vocab at 0x7f6140b90c50>,
#  'نورنبيرغ': <gensim.models.keyedvectors.Vocab at 0x7f6140b90cc0>,
#  'نورمبرغ': <gensim.models.keyedvectors.Vocab at 0x7f6140b90cf8>,
#  'الامريكية': <gensim.models.keyedvectors.Vocab at 0x7f6140b90d30>,
#  'ثالث': <gensim.models.keyedvectors.Vocab at 0x7f6140b90d68>,
#  'غليزان': <gensim.models.keyedvectors.Vocab at 0x7f6140b90da0>,
#  'البواقي': <gensim.models.keyedvectors.Vocab at 0x7f6140b90dd8>,
#  '(الجزائر)': <gensim.models.keyedvectors.Vocab at 0x7f6140b90e10>,
#  'الحميد': <gensim.models.keyedvectors.Vocab at 0x7f6140b90eb8>,
#  'باديس': <gensim.models.keyedvectors.Vocab at 0x7f6140b90ef0>,
#  'البشير': <gensim.models.keyedvectors.Vocab at 0x7f6140b90f60>,
#  'الإبراهيمي': <gensim.models.keyedvectors.Vocab at 0x7f6140b90fd0>,
#  'توفيق': <gensim.models.keyedvectors.Vocab at 0x7f6140b907b8>,
#  'المدني': <gensim.models.keyedvectors.Vocab at 0x7f6140b90f28>,
#  'العقبي': <gensim.models.keyedvectors.Vocab at 0x7f613f57a160>,
#  'ستالين': <gensim.models.keyedvectors.Vocab at 0x7f613f57a208>,
#  'ماجد': <gensim.models.keyedvectors.Vocab at 0x7f613f57a240>,
#  'نبي': <gensim.models.keyedvectors.Vocab at 0x7f613f57a2b0>,
#  'السامية': <gensim.models.keyedvectors.Vocab at 0x7f613f57a2e8>,
#  'ألطية': <gensim.models.keyedvectors.Vocab at 0x7f613f57a358>,
#  'المقدس': <gensim.models.keyedvectors.Vocab at 0x7f613f57a390>,
#  'لاتينية': <gensim.models.keyedvectors.Vocab at 0x7f613f57a3c8>,
#  'الذهبي': <gensim.models.keyedvectors.Vocab at 0x7f613f57a400>,
#  'اليابان': <gensim.models.keyedvectors.Vocab at 0x7f613f57a438>,
#  'أسوكا': <gensim.models.keyedvectors.Vocab at 0x7f613f57a4e0>,
#  'نارا': <gensim.models.keyedvectors.Vocab at 0x7f613f57a518>,
#  '(عشيرة)': <gensim.models.keyedvectors.Vocab at 0x7f613f57a588>,
#  'نو': <gensim.models.keyedvectors.Vocab at 0x7f613f57a5c0>,
#  'غنجي': <gensim.models.keyedvectors.Vocab at 0x7f613f57a5f8>,
#  'كاماكورا': <gensim.models.keyedvectors.Vocab at 0x7f613f57a6a0>,
#  'نوبل': <gensim.models.keyedvectors.Vocab at 0x7f613f57a6d8>,
#  'الأيوبية': <gensim.models.keyedvectors.Vocab at 0x7f613f57a710>,
#  'عباد': <gensim.models.keyedvectors.Vocab at 0x7f613f57aba8>,
#  'زيان': <gensim.models.keyedvectors.Vocab at 0x7f613f57abe0>,
#  'العلويين': <gensim.models.keyedvectors.Vocab at 0x7f613f57ac18>,
#  'الحاكمة': <gensim.models.keyedvectors.Vocab at 0x7f613f57ada0>,
#  'الأفشارية': <gensim.models.keyedvectors.Vocab at 0x7f613f57a4a8>,
#  'الأفطس': <gensim.models.keyedvectors.Vocab at 0x7f613f57af60>,
#  'عامر': <gensim.models.keyedvectors.Vocab at 0x7f613dbbe358>,
#  '(الأندلس)': <gensim.models.keyedvectors.Vocab at 0x7f613dbbe438>,
#  'الروم': <gensim.models.keyedvectors.Vocab at 0x7f613dbbe4a8>,
#  'قويونلو': <gensim.models.keyedvectors.Vocab at 0x7f613dbbe908>,
#  'الجنوبية': <gensim.models.keyedvectors.Vocab at 0x7f613dbbeb00>,
#  'السلجوقية': <gensim.models.keyedvectors.Vocab at 0x7f6140c182b0>,
#  'غوريون': <gensim.models.keyedvectors.Vocab at 0x7f6140c18358>,
#  'الله': <gensim.models.keyedvectors.Vocab at 0x7f6140c186a0>,
#  'المقفع': <gensim.models.keyedvectors.Vocab at 0x7f613dbc47b8>,
#  'إسرائيل': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2080>,
#  'عبرية': <gensim.models.keyedvectors.Vocab at 0x7f6140bf20b8>,
#  'رابين': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2128>,
#  'سريانية': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2160>,
#  'البصري': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2208>,
#  'دير': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2240>,
#  'الأوروبي': <gensim.models.keyedvectors.Vocab at 0x7f6140bf22b0>,
#  'الصدر': <gensim.models.keyedvectors.Vocab at 0x7f6140bf22e8>,
#  'شامير': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2320>,
#  'بيريز': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2358>,
#  'إسحاق': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2438>,
#  'الكندي': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2518>,
#  '(فيزياء)': <gensim.models.keyedvectors.Vocab at 0x7f6140bf25c0>,
#  'رئاسية': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2630>,
#  'جزائرية': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2668>,
#  'أبريل': <gensim.models.keyedvectors.Vocab at 0x7f6140bf26a0>,
#  'باراك': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2710>,
#  'والت': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2a90>,
#  'ديزني': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2b00>,
#  '(شهر)': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2b70>,
#  'يناير': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2be0>,
#  'فبراير': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2a20>,
#  'الحكومة': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2c50>,
#  'الإسرائيلية': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2c88>,
#  'مطلوبة': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2d30>,
#  'مشهورة': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2d68>,
#  'قتالية': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2f60>,
#  'طويلة': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2fd0>,
#  'كمبيوتر': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2c18>,
#  'بحث': <gensim.models.keyedvectors.Vocab at 0x7f6140bf24a8>,
#  '(ويب)': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2cc0>,
#  'اليمن': <gensim.models.keyedvectors.Vocab at 0x7f6140bf2748>,
#  'حماة': <gensim.models.keyedvectors.Vocab at 0x7f613da813c8>,
#  'حلب': <gensim.models.keyedvectors.Vocab at 0x7f613da81438>,
#  'حمص': <gensim.models.keyedvectors.Vocab at 0x7f613da81978>,
#  'دمشق': <gensim.models.keyedvectors.Vocab at 0x7f613da819b0>,
#  'ديار': <gensim.models.keyedvectors.Vocab at 0x7f613da81710>,
#  'بكر': <gensim.models.keyedvectors.Vocab at 0x7f613da81748>,
#  'المملوكية': <gensim.models.keyedvectors.Vocab at 0x7f6140c04c18>,
#  'العزيز': <gensim.models.keyedvectors.Vocab at 0x7f6140c048d0>,
#  'سعود': <gensim.models.keyedvectors.Vocab at 0x7f6140c044a8>,
#  'لينكس': <gensim.models.keyedvectors.Vocab at 0x7f6140c04518>,
#  '(إسلام)': <gensim.models.keyedvectors.Vocab at 0x7f6140c04630>,
#  'جبريل': <gensim.models.keyedvectors.Vocab at 0x7f6140c04668>,
#  'غزة': <gensim.models.keyedvectors.Vocab at 0x7f6140c04048>,
#  '(مهنة)': <gensim.models.keyedvectors.Vocab at 0x7f6140c04080>,
#  'كنعانية': <gensim.models.keyedvectors.Vocab at 0x7f6140c040f0>,
#  'روزفلت': <gensim.models.keyedvectors.Vocab at 0x7f6140c04128>,
#  'طفيل': <gensim.models.keyedvectors.Vocab at 0x7f6140c04240>,
#  'تشرشل': <gensim.models.keyedvectors.Vocab at 0x7f6140c042b0>,
#  'عرفات': <gensim.models.keyedvectors.Vocab at 0x7f6140c042e8>,
#  'الأعضاء': <gensim.models.keyedvectors.Vocab at 0x7f6140c04358>,
#  'الأمم': <gensim.models.keyedvectors.Vocab at 0x7f6140c04390>,
#  'مايو': <gensim.models.keyedvectors.Vocab at 0x7f6140c043c8>,
#  'خادم': <gensim.models.keyedvectors.Vocab at 0x7f6140c04438>,
#  'جافا': <gensim.models.keyedvectors.Vocab at 0x7f6140c04470>,
#  'يونيو': <gensim.models.keyedvectors.Vocab at 0x7f6140c04c88>,
#  'مبارك': <gensim.models.keyedvectors.Vocab at 0x7f6140c04cc0>,
#  'جزائري': <gensim.models.keyedvectors.Vocab at 0x7f6140c04da0>,
#  'ميلادي': <gensim.models.keyedvectors.Vocab at 0x7f6140c04dd8>,
#  'غربي': <gensim.models.keyedvectors.Vocab at 0x7f6140c046a0>,
#  'يوليو': <gensim.models.keyedvectors.Vocab at 0x7f6140c04748>,
#  'أغسطس': <gensim.models.keyedvectors.Vocab at 0x7f6140c04780>,
#  'عفان': <gensim.models.keyedvectors.Vocab at 0x7f6140c047b8>,
#  'هجري': <gensim.models.keyedvectors.Vocab at 0x7f6140c04f60>,
#  'الوطنية': <gensim.models.keyedvectors.Vocab at 0x7f6140c04f98>,
#  'الفلسطينية': <gensim.models.keyedvectors.Vocab at 0x7f6140c04fd0>,
#  'العراق': <gensim.models.keyedvectors.Vocab at 0x7f613675b780>,
#  'مارس': <gensim.models.keyedvectors.Vocab at 0x7f613675b7f0>,
#  'العثمانية': <gensim.models.keyedvectors.Vocab at 0x7f613675b940>,
#  'فاطمية': <gensim.models.keyedvectors.Vocab at 0x7f613675bcf8>,
#  'التيمورية': <gensim.models.keyedvectors.Vocab at 0x7f613675bf60>,
#  'بحوث': <gensim.models.keyedvectors.Vocab at 0x7f613675b390>,
#  'إعلام': <gensim.models.keyedvectors.Vocab at 0x7f613675b400>,
#  'الشرق': <gensim.models.keyedvectors.Vocab at 0x7f613675b470>,
#  'الأوسط': <gensim.models.keyedvectors.Vocab at 0x7f613675b4a8>,
#  'يابانية': <gensim.models.keyedvectors.Vocab at 0x7f613675b550>,
#  'شفوي': <gensim.models.keyedvectors.Vocab at 0x7f613675b668>,
#  'أكتوبر': <gensim.models.keyedvectors.Vocab at 0x7f613610a9b0>,
#  'البحث': <gensim.models.keyedvectors.Vocab at 0x7f613610a9e8>,
#  'نوفمبر': <gensim.models.keyedvectors.Vocab at 0x7f613610aac8>,
#  'قديمة': <gensim.models.keyedvectors.Vocab at 0x7f613610acc0>,
#  'النطق': <gensim.models.keyedvectors.Vocab at 0x7f613610af60>,
#  'لساني': <gensim.models.keyedvectors.Vocab at 0x7f613610a048>,
#  'جوبز': <gensim.models.keyedvectors.Vocab at 0x7f613610a0b8>,
#  'عقب': <gensim.models.keyedvectors.Vocab at 0x7f613610a0f0>,
#  'إن': <gensim.models.keyedvectors.Vocab at 0x7f613610a128>,
#  'المختار': <gensim.models.keyedvectors.Vocab at 0x7f613610a160>,
#  '(اسم)': <gensim.models.keyedvectors.Vocab at 0x7f613610a1d0>,
#  'كولومبوس': <gensim.models.keyedvectors.Vocab at 0x7f613610a208>,
#  'مربع': <gensim.models.keyedvectors.Vocab at 0x7f613610a240>,
#  'الشهداء': <gensim.models.keyedvectors.Vocab at 0x7f613610a278>,
#  '(فلسطين)': <gensim.models.keyedvectors.Vocab at 0x7f613610a2b0>,
#  'يونس': <gensim.models.keyedvectors.Vocab at 0x7f613610a320>,
#  'كشك': <gensim.models.keyedvectors.Vocab at 0x7f613610a390>,
#  'الرجاء': <gensim.models.keyedvectors.Vocab at 0x7f613610a3c8>,
#  'الصالح': <gensim.models.keyedvectors.Vocab at 0x7f613610a400>,
#  'علي': <gensim.models.keyedvectors.Vocab at 0x7f613610a438>,
#  'الحمدانية': <gensim.models.keyedvectors.Vocab at 0x7f613610a358>,
#  'الغزنوية': <gensim.models.keyedvectors.Vocab at 0x7f613610a470>,
#  'كتابة': <gensim.models.keyedvectors.Vocab at 0x7f613610a4a8>,
#  'ميكروسوفت': <gensim.models.keyedvectors.Vocab at 0x7f613610a4e0>,
#  '(أوهايو)': <gensim.models.keyedvectors.Vocab at 0x7f613610a518>,
#  'غاري': <gensim.models.keyedvectors.Vocab at 0x7f613610a550>,
#  'يو': <gensim.models.keyedvectors.Vocab at 0x7f613610a588>,
#  'إس': <gensim.models.keyedvectors.Vocab at 0x7f613610a5f8>,
#  'كول': <gensim.models.keyedvectors.Vocab at 0x7f613610a668>,
#  'كبيسة': <gensim.models.keyedvectors.Vocab at 0x7f613610a6a0>,
#  'ديسمبر': <gensim.models.keyedvectors.Vocab at 0x7f613610a6d8>,
#  'الكتابة': <gensim.models.keyedvectors.Vocab at 0x7f613610a710>,
#  'أسنان': <gensim.models.keyedvectors.Vocab at 0x7f613610a748>,
#  'نقل': <gensim.models.keyedvectors.Vocab at 0x7f613610a780>,
#  'مجلس': <gensim.models.keyedvectors.Vocab at 0x7f613610a7b8>,
#  'مؤسسة': <gensim.models.keyedvectors.Vocab at 0x7f613610a860>,
#  'ويكيميديا': <gensim.models.keyedvectors.Vocab at 0x7f613610a898>,
#  'الظواهري': <gensim.models.keyedvectors.Vocab at 0x7f613610a8d0>,
#  'أنور': <gensim.models.keyedvectors.Vocab at 0x7f613610a940>,
#  'السادات': <gensim.models.keyedvectors.Vocab at 0x7f613610a908>,
#  'السريع': <gensim.models.keyedvectors.Vocab at 0x7f613610a7f0>,
#  'عبد': <gensim.models.keyedvectors.Vocab at 0x7f6136657048>,
#  'الناصر': <gensim.models.keyedvectors.Vocab at 0x7f61366570b8>,
#  'الأموية': <gensim.models.keyedvectors.Vocab at 0x7f61366570f0>,
#  'الأندلس': <gensim.models.keyedvectors.Vocab at 0x7f6136657080>,
#  'عصام': <gensim.models.keyedvectors.Vocab at 0x7f6136657128>,
#  'مصعب': <gensim.models.keyedvectors.Vocab at 0x7f6136657198>,
#  'الزرقاوي': <gensim.models.keyedvectors.Vocab at 0x7f6136657208>,
#  'اثنا': <gensim.models.keyedvectors.Vocab at 0x7f6136657240>,
#  'عشرية': <gensim.models.keyedvectors.Vocab at 0x7f61366572b0>,
#  'انتخابي': <gensim.models.keyedvectors.Vocab at 0x7f6136657320>,
#  'باريتو': <gensim.models.keyedvectors.Vocab at 0x7f6136657358>,
#  'غاندي': <gensim.models.keyedvectors.Vocab at 0x7f6136657390>,
#  'مثلثات': <gensim.models.keyedvectors.Vocab at 0x7f61366573c8>,
#  'اغريقية': <gensim.models.keyedvectors.Vocab at 0x7f6136657470>,
#  '(ميثولوجيا)': <gensim.models.keyedvectors.Vocab at 0x7f6136657438>,
#  'شخصية': <gensim.models.keyedvectors.Vocab at 0x7f6136657400>,
#  'محلية': <gensim.models.keyedvectors.Vocab at 0x7f6136657588>,
#  'واسعة': <gensim.models.keyedvectors.Vocab at 0x7f61366575f8>,
#  'مرن': <gensim.models.keyedvectors.Vocab at 0x7f6136657668>,
#  'ماركس': <gensim.models.keyedvectors.Vocab at 0x7f6136657710>,
#  'الموسيقى': <gensim.models.keyedvectors.Vocab at 0x7f6136657780>,
#  'الكلاسيكية': <gensim.models.keyedvectors.Vocab at 0x7f61366577f0>,
#  'دايان': <gensim.models.keyedvectors.Vocab at 0x7f6136657828>,
#  'سليم': <gensim.models.keyedvectors.Vocab at 0x7f6136657940>,
#  'المنصور': <gensim.models.keyedvectors.Vocab at 0x7f6136657978>,
#  'إكس': <gensim.models.keyedvectors.Vocab at 0x7f61366579e8>,
#  'ضبابي': <gensim.models.keyedvectors.Vocab at 0x7f6136657a20>,
#  'الإخشيدية': <gensim.models.keyedvectors.Vocab at 0x7f61366574e0>,
#  'الطولونية': <gensim.models.keyedvectors.Vocab at 0x7f6136657a90>,
#  'هود': <gensim.models.keyedvectors.Vocab at 0x7f6136657b38>,
#  'الصفوية': <gensim.models.keyedvectors.Vocab at 0x7f6136657c18>,
#  'شوي': <gensim.models.keyedvectors.Vocab at 0x7f6136657cf8>,
#  'بيان': <gensim.models.keyedvectors.Vocab at 0x7f6136657d30>,
#  'ورقية': <gensim.models.keyedvectors.Vocab at 0x7f6136657da0>,
#  'الصفحة': <gensim.models.keyedvectors.Vocab at 0x7f6136657e80>,
#  'المختارة': <gensim.models.keyedvectors.Vocab at 0x7f6136657eb8>,
#  'البنا': <gensim.models.keyedvectors.Vocab at 0x7f6136657f28>,
#  'علاوي': <gensim.models.keyedvectors.Vocab at 0x7f613dbcbc50>,
#  'فيروس': <gensim.models.keyedvectors.Vocab at 0x7f613dbcbcc0>,
#  'إيبولا': <gensim.models.keyedvectors.Vocab at 0x7f613dbcbcf8>,
#  'وأسلحة': <gensim.models.keyedvectors.Vocab at 0x7f613dbcbb70>,
#  'الدمار': <gensim.models.keyedvectors.Vocab at 0x7f613dbcb128>,
#  'الشامل': <gensim.models.keyedvectors.Vocab at 0x7f613dbcb160>,
#  'الثالث': <gensim.models.keyedvectors.Vocab at 0x7f613dbcb400>,
#  'ريغان': <gensim.models.keyedvectors.Vocab at 0x7f613dbcb518>,
#  'الفلسطيني': <gensim.models.keyedvectors.Vocab at 0x7f613dbcb748>,
#  '(المغرب)': <gensim.models.keyedvectors.Vocab at 0x7f613dbcb780>,
#  'الذهب': <gensim.models.keyedvectors.Vocab at 0x7f613dbcb198>,
#  'الاسد': <gensim.models.keyedvectors.Vocab at 0x7f613dbcb860>,
#  'الأسد': <gensim.models.keyedvectors.Vocab at 0x7f613dbcb9e8>,
#  '(طائفة)': <gensim.models.keyedvectors.Vocab at 0x7f613dbcba20>,
#  'مانديلا': <gensim.models.keyedvectors.Vocab at 0x7f613da49e48>,
#  'أو': <gensim.models.keyedvectors.Vocab at 0x7f613de1cf60>,
#  'ترميز': <gensim.models.keyedvectors.Vocab at 0x7f613da53e80>,
#  'النص': <gensim.models.keyedvectors.Vocab at 0x7f613db3e518>,
#  'الفائق': <gensim.models.keyedvectors.Vocab at 0x7f613db3e978>,
#  'البرامج': <gensim.models.keyedvectors.Vocab at 0x7f613db9bbe0>,
#  'الجولان': <gensim.models.keyedvectors.Vocab at 0x7f613db9bc88>,
#  'زنكي': <gensim.models.keyedvectors.Vocab at 0x7f613db9b668>,
#  'عيد': <gensim.models.keyedvectors.Vocab at 0x7f613db9bef0>,
#  'الخيرية': <gensim.models.keyedvectors.Vocab at 0x7f613db9bdd8>,
#  'فلاح': <gensim.models.keyedvectors.Vocab at 0x7f613da5e4a8>,
#  'حثلين': <gensim.models.keyedvectors.Vocab at 0x7f613da5e630>,
#  'الرسائل': <gensim.models.keyedvectors.Vocab at 0x7f613da5e9e8>,
#  'شرقية': <gensim.models.keyedvectors.Vocab at 0x7f613da686a0>,
#  'ثاني': <gensim.models.keyedvectors.Vocab at 0x7f613da68860>,
#  'أحمر': <gensim.models.keyedvectors.Vocab at 0x7f613da68e10>,
#  'أبيض': <gensim.models.keyedvectors.Vocab at 0x7f613da68e48>,
#  'قطبي': <gensim.models.keyedvectors.Vocab at 0x7f613da68978>,
#  '(كوكب)': <gensim.models.keyedvectors.Vocab at 0x7f613da68048>,
#  'أخضر': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca048>,
#  'متعددة': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca080>,
#  'تفاعلية': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca0b8>,
#  'حي': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca0f0>,
#  'إي': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca128>,
#  'جي': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca160>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca198>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca1d0>,
#  'أم': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca208>,
#  'حاسوبية': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca240>,
#  'رشيد': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca278>,
#  '(هندسة)': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca2e8>,
#  'اوسلو': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca320>,
#  'قائم': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca3c8>,
#  'أسود': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca400>,
#  'الأردن': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca438>,
#  'ملكي': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca4a8>,
#  'شوقي': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca4e0>,
#  'رشد': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca550>,
#  'لحم': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca588>,
#  'الغربية': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca5c0>,
#  'العذراء': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca6a0>,
#  'كيميائي': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca6d8>,
#  'سامرية': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca710>,
#  'فيزيائية': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca748>,
#  'سوداء': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca7b8>,
#  'دوري': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca828>,
#  'الإسرائيلي': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca860>,
#  'الضفة': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca898>,
#  'عضوية': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca8d0>,
#  'النسبية': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca940>,
#  'نسبية': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca978>,
#  'عامة': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca9b0>,
#  'عد': <gensim.models.keyedvectors.Vocab at 0x7f613f3ca9e8>,
#  'رومانية': <gensim.models.keyedvectors.Vocab at 0x7f613f3caa20>,
#  'السوفيتي': <gensim.models.keyedvectors.Vocab at 0x7f613f3cab00>,
#  'البعث': <gensim.models.keyedvectors.Vocab at 0x7f613f3cab70>,
#  'الاشتراكي': <gensim.models.keyedvectors.Vocab at 0x7f613f3caba8>,
#  'الميت': <gensim.models.keyedvectors.Vocab at 0x7f613f3cabe0>,
#  'الكيميائية': <gensim.models.keyedvectors.Vocab at 0x7f613f3cac18>,
#  'جنبلاط': <gensim.models.keyedvectors.Vocab at 0x7f613f3cac50>,
#  'سباستيان': <gensim.models.keyedvectors.Vocab at 0x7f613f3cac88>,
#  'باخ': <gensim.models.keyedvectors.Vocab at 0x7f613f3cacc0>,
#  'سيباستيان': <gensim.models.keyedvectors.Vocab at 0x7f613f3cad30>,
#  'مرتبة': <gensim.models.keyedvectors.Vocab at 0x7f613f3cad68>,
#  'حسب': <gensim.models.keyedvectors.Vocab at 0x7f613f3cada0>,
#  'العنوان': <gensim.models.keyedvectors.Vocab at 0x7f613f3cadd8>,
#  'مصر': <gensim.models.keyedvectors.Vocab at 0x7f613f3cae10>,
#  'صليبية': <gensim.models.keyedvectors.Vocab at 0x7f613f3cae48>,
#  'دروز': <gensim.models.keyedvectors.Vocab at 0x7f613f3cae80>,
#  'البجا': <gensim.models.keyedvectors.Vocab at 0x7f613f3caeb8>,
#  'حطين': <gensim.models.keyedvectors.Vocab at 0x7f613f3caef0>,
#  'عربية': <gensim.models.keyedvectors.Vocab at 0x7f613f3caf28>,
#  'جند': <gensim.models.keyedvectors.Vocab at 0x7f613f3caf60>,
#  'الوطن': <gensim.models.keyedvectors.Vocab at 0x7f613f3caf98>,
#  'الخطيب': <gensim.models.keyedvectors.Vocab at 0x7f613f3cafd0>,
#  'اللغات': <gensim.models.keyedvectors.Vocab at 0x7f613f3cab38>,
#  'الطبيعية': <gensim.models.keyedvectors.Vocab at 0x7f613f3cacf8>,
#  'لينين': <gensim.models.keyedvectors.Vocab at 0x7f61366bc048>,
#  '(فرقة': <gensim.models.keyedvectors.Vocab at 0x7f61366bc080>,
#  'موسيقية)': <gensim.models.keyedvectors.Vocab at 0x7f61366bc0b8>,
#  'أمريكا': <gensim.models.keyedvectors.Vocab at 0x7f61366bc0f0>,
#  'تسي': <gensim.models.keyedvectors.Vocab at 0x7f61366bc128>,
#  'تونغ': <gensim.models.keyedvectors.Vocab at 0x7f61366bc160>,
#  'هتلر': <gensim.models.keyedvectors.Vocab at 0x7f61366bc198>,
#  'القبطية': <gensim.models.keyedvectors.Vocab at 0x7f61366bc1d0>,
#  'الأرثوذكسية': <gensim.models.keyedvectors.Vocab at 0x7f61366bc208>,
#  'القطبي': <gensim.models.keyedvectors.Vocab at 0x7f61366bc278>,
#  'سوفيتي': <gensim.models.keyedvectors.Vocab at 0x7f61366bc2b0>,
#  'الهاتف': <gensim.models.keyedvectors.Vocab at 0x7f61366bc2e8>,
#  'الدولي': <gensim.models.keyedvectors.Vocab at 0x7f61366bc358>,
#  'الشرقية': <gensim.models.keyedvectors.Vocab at 0x7f61366bc390>,
#  'فرساي': <gensim.models.keyedvectors.Vocab at 0x7f61366bc3c8>,
#  'غوبلز': <gensim.models.keyedvectors.Vocab at 0x7f61366bc4e0>,
#  'هيملر': <gensim.models.keyedvectors.Vocab at 0x7f61366bc550>,
#  'خاصة': <gensim.models.keyedvectors.Vocab at 0x7f61366bc588>,
#  'فاصل': <gensim.models.keyedvectors.Vocab at 0x7f61366bc5c0>,
#  'الأولمبية': <gensim.models.keyedvectors.Vocab at 0x7f61366bc5f8>,
#  'الأخير': <gensim.models.keyedvectors.Vocab at 0x7f61366bc630>,
#  'البيضاء': <gensim.models.keyedvectors.Vocab at 0x7f61366bc668>,
#  'والهرسك': <gensim.models.keyedvectors.Vocab at 0x7f61366bc6d8>,
#  'التشيكية': <gensim.models.keyedvectors.Vocab at 0x7f61366bc710>,
#  'مقدونيا': <gensim.models.keyedvectors.Vocab at 0x7f61366bc748>,
#  'مارينو': <gensim.models.keyedvectors.Vocab at 0x7f61366bc780>,
#  'بيساو': <gensim.models.keyedvectors.Vocab at 0x7f61366bc7b8>,
#  'فاسو': <gensim.models.keyedvectors.Vocab at 0x7f61366bc7f0>,
#  'تبان': <gensim.models.keyedvectors.Vocab at 0x7f61366bc828>,
#  '(قطر)': <gensim.models.keyedvectors.Vocab at 0x7f61366bc860>,
#  'الأولى': <gensim.models.keyedvectors.Vocab at 0x7f61366bc898>,
#  'الباردة': <gensim.models.keyedvectors.Vocab at 0x7f61366bc8d0>,
#  'اصطناعي': <gensim.models.keyedvectors.Vocab at 0x7f61366bc908>,
#  'الراشدون': <gensim.models.keyedvectors.Vocab at 0x7f61366bc940>,
#  'لبنان': <gensim.models.keyedvectors.Vocab at 0x7f61366bc978>,
#  'الشعبية': <gensim.models.keyedvectors.Vocab at 0x7f61366bc9b0>,
#  'لتحرير': <gensim.models.keyedvectors.Vocab at 0x7f61366bc9e8>,
#  'حداد': <gensim.models.keyedvectors.Vocab at 0x7f61366bcb00>,
#  'الثعلب': <gensim.models.keyedvectors.Vocab at 0x7f61366bcb38>,
#  'فرانسيسكو': <gensim.models.keyedvectors.Vocab at 0x7f61366bcb70>,
#  'زايد': <gensim.models.keyedvectors.Vocab at 0x7f61366bcbe0>,
#  'أل': <gensim.models.keyedvectors.Vocab at 0x7f61366bcc18>,
#  'العظيم': <gensim.models.keyedvectors.Vocab at 0x7f61366bcc50>,
#  'الإنفجار': <gensim.models.keyedvectors.Vocab at 0x7f61366bcc88>,
#  'الكبير': <gensim.models.keyedvectors.Vocab at 0x7f61366bccc0>,
#  '(كيمياء)': <gensim.models.keyedvectors.Vocab at 0x7f61366bcd68>,
#  'جنسية': <gensim.models.keyedvectors.Vocab at 0x7f61366bcda0>,
#  'قياس': <gensim.models.keyedvectors.Vocab at 0x7f61366bcdd8>,
#  'القياس': <gensim.models.keyedvectors.Vocab at 0x7f61366bcf28>,
#  'اعتقال': <gensim.models.keyedvectors.Vocab at 0x7f61366bcf60>,
#  'ساحة': <gensim.models.keyedvectors.Vocab at 0x7f61366bcf98>,
#  'جنسي': <gensim.models.keyedvectors.Vocab at 0x7f61366bcfd0>,
#  'الجنسي': <gensim.models.keyedvectors.Vocab at 0x7f61366bcac8>,
#  'ارضية': <gensim.models.keyedvectors.Vocab at 0x7f61368b7048>,
#  'يونكس': <gensim.models.keyedvectors.Vocab at 0x7f61368b7080>,
#  'الموريتاني': <gensim.models.keyedvectors.Vocab at 0x7f61368b70b8>,
#  'تحرير': <gensim.models.keyedvectors.Vocab at 0x7f61368b70f0>,
#  'فلسطينية': <gensim.models.keyedvectors.Vocab at 0x7f61368b7128>,
#  'متر': <gensim.models.keyedvectors.Vocab at 0x7f61368b7160>,
#  'سكانية': <gensim.models.keyedvectors.Vocab at 0x7f61368b7198>,
#  'الكريم': <gensim.models.keyedvectors.Vocab at 0x7f61368b71d0>,
#  'ميرغني': <gensim.models.keyedvectors.Vocab at 0x7f61368b7208>,
#  'خامسة': <gensim.models.keyedvectors.Vocab at 0x7f61368b7240>,
#  'الأطفال': <gensim.models.keyedvectors.Vocab at 0x7f61368b7278>,
#  'الصليبية': <gensim.models.keyedvectors.Vocab at 0x7f61368b72b0>,
#  'محمية': <gensim.models.keyedvectors.Vocab at 0x7f61368b72e8>,
#  'إتش': <gensim.models.keyedvectors.Vocab at 0x7f61368b7320>,
#  'نشطة': <gensim.models.keyedvectors.Vocab at 0x7f61368b7358>,
#  'عمر': <gensim.models.keyedvectors.Vocab at 0x7f61368b7390>,
#  'الثالثة': <gensim.models.keyedvectors.Vocab at 0x7f61368b73c8>,
#  'الرحمن': <gensim.models.keyedvectors.Vocab at 0x7f61368b7400>,
#  'سوار': <gensim.models.keyedvectors.Vocab at 0x7f61368b7438>,
#  'السابعة': <gensim.models.keyedvectors.Vocab at 0x7f61368b74a8>,
#  '(علم)': <gensim.models.keyedvectors.Vocab at 0x7f61368b74e0>,
#  'رابعة': <gensim.models.keyedvectors.Vocab at 0x7f61368b7550>,
#  'درويش': <gensim.models.keyedvectors.Vocab at 0x7f61368b75f8>,
#  'المهجر': <gensim.models.keyedvectors.Vocab at 0x7f61368b7630>,
#  'خليل': <gensim.models.keyedvectors.Vocab at 0x7f61368b7668>,
#  'جبران': <gensim.models.keyedvectors.Vocab at 0x7f61368b76a0>,
#  'الأحزاب': <gensim.models.keyedvectors.Vocab at 0x7f61368b76d8>,
#  'السياسية': <gensim.models.keyedvectors.Vocab at 0x7f61368b7710>,
#  'نعيمة': <gensim.models.keyedvectors.Vocab at 0x7f61368b7748>,
#  'كارتر': <gensim.models.keyedvectors.Vocab at 0x7f61368b7780>,
#  'ناجي': <gensim.models.keyedvectors.Vocab at 0x7f61368b77b8>,
#  'العضوية': <gensim.models.keyedvectors.Vocab at 0x7f61368b77f0>,
#  'الوهاب': <gensim.models.keyedvectors.Vocab at 0x7f61368b7828>,
#  'رضا': <gensim.models.keyedvectors.Vocab at 0x7f61368b78d0>,
#  'بهلوي': <gensim.models.keyedvectors.Vocab at 0x7f61368b7908>,
#  'الشعب': <gensim.models.keyedvectors.Vocab at 0x7f61368b7940>,
#  'القرضاوي': <gensim.models.keyedvectors.Vocab at 0x7f61368b7978>,
#  'الشقيري': <gensim.models.keyedvectors.Vocab at 0x7f61368b79e8>,
#  '(سياسي': <gensim.models.keyedvectors.Vocab at 0x7f61368b7a20>,
#  'سادسة': <gensim.models.keyedvectors.Vocab at 0x7f61368b7a58>,
#  'المغرب': <gensim.models.keyedvectors.Vocab at 0x7f61368b7a90>,
#  '(ولاية)': <gensim.models.keyedvectors.Vocab at 0x7f61368b7ac8>,
#  'الإنترنت': <gensim.models.keyedvectors.Vocab at 0x7f61368b7b00>,
#  'مجانية': <gensim.models.keyedvectors.Vocab at 0x7f61368b7b38>,
#  'تجريبية': <gensim.models.keyedvectors.Vocab at 0x7f61368b7b70>,
#  'كاسترو': <gensim.models.keyedvectors.Vocab at 0x7f61368b7be0>,
#  'القطري': <gensim.models.keyedvectors.Vocab at 0x7f61368b7c18>,
#  'الخضراء': <gensim.models.keyedvectors.Vocab at 0x7f61368b7c50>,
#  'هايدن': <gensim.models.keyedvectors.Vocab at 0x7f61368b7c88>,
#  'فان': <gensim.models.keyedvectors.Vocab at 0x7f61368b7cc0>,
#  'بيتهوفن': <gensim.models.keyedvectors.Vocab at 0x7f61368b7cf8>,
#  'موزارت': <gensim.models.keyedvectors.Vocab at 0x7f61368b7d30>,
#  'إليتش': <gensim.models.keyedvectors.Vocab at 0x7f61368b7da0>,
#  'لودفيج': <gensim.models.keyedvectors.Vocab at 0x7f61368b7dd8>,
#  'أماديوس': <gensim.models.keyedvectors.Vocab at 0x7f61368b7e10>,
#  'سامي': <gensim.models.keyedvectors.Vocab at 0x7f61368b7ef0>,
#  'البارودي': <gensim.models.keyedvectors.Vocab at 0x7f61368b7f28>,
#  'المسيح': <gensim.models.keyedvectors.Vocab at 0x7f61368b7f60>,
#  '(لغة': <gensim.models.keyedvectors.Vocab at 0x7f61368b7f98>,
#  'برمجة)': <gensim.models.keyedvectors.Vocab at 0x7f61368b7fd0>,
#  'باز': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa358>,
#  'الأسود': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa3c8>,
#  '(رياضيات)': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa400>,
#  'ألمانيا': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa438>,
#  'الإتحاد': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa470>,
#  'نووي': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa4e0>,
#  'إبراهيم': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa518>,
#  'مجرد': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa550>,
#  'فور': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa588>,
#  'خاملة': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa5c0>,
#  'ألبانية': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa668>,
#  'الألبانية': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa710>,
#  'لغوية': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa748>,
#  'اللغوية': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa780>,
#  'ماثيو': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa828>,
#  'إدخال': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa860>,
#  'الإخراج': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa898>,
#  '(حاسوب)': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa8d0>,
#  'حاسوب': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa9e8>,
#  'طروادة': <gensim.models.keyedvectors.Vocab at 0x7f613f5aaa58>,
#  'الحواسيب': <gensim.models.keyedvectors.Vocab at 0x7f613f5aaa90>,
#  'الخصوصية': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa4a8>,
#  'لوحة': <gensim.models.keyedvectors.Vocab at 0x7f613f5aab38>,
#  'مفاتيح': <gensim.models.keyedvectors.Vocab at 0x7f613f5aacf8>,
#  'النفس': <gensim.models.keyedvectors.Vocab at 0x7f613f5aada0>,
#  'التشغيل': <gensim.models.keyedvectors.Vocab at 0x7f613f5aae10>,
#  'أوفيس.أورج': <gensim.models.keyedvectors.Vocab at 0x7f613f5aaeb8>,
#  'التحويل': <gensim.models.keyedvectors.Vocab at 0x7f613f5aaef0>,
#  'بايك': <gensim.models.keyedvectors.Vocab at 0x7f613f5aaf28>,
#  'تومسن': <gensim.models.keyedvectors.Vocab at 0x7f613f5aaf60>,
#  'حماية': <gensim.models.keyedvectors.Vocab at 0x7f613f5aaf98>,
#  '(حوسبة)': <gensim.models.keyedvectors.Vocab at 0x7f613f5aaba8>,
#  'أوفيس': <gensim.models.keyedvectors.Vocab at 0x7f613f5aabe0>,
#  'ويندوز': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa048>,
#  'الوصول': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa080>,
#  'العشوائي': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa0b8>,
#  'نوبية': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa128>,
#  'النوبية': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa198>,
#  'النوبة': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa1d0>,
#  'السواحلية': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa208>,
#  'صحراوية': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa240>,
#  'طبريا': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa278>,
#  'الجمل': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa2b0>,
#  'البنات': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa2e8>,
#  'الخالدي': <gensim.models.keyedvectors.Vocab at 0x7f613f5aa320>,
#  'الذري': <gensim.models.keyedvectors.Vocab at 0x7f613f5aaac8>,
#  '3166': <gensim.models.keyedvectors.Vocab at 0x7f613f5aafd0>,
#  'هرمز': <gensim.models.keyedvectors.Vocab at 0x7f61365f2da0>,
#  'الموحدة': <gensim.models.keyedvectors.Vocab at 0x7f61365f2ef0>,
#  'الوحدات': <gensim.models.keyedvectors.Vocab at 0x7f61365f2f28>,
#  'العراقي': <gensim.models.keyedvectors.Vocab at 0x7f61365f2d30>,
#  'بنت': <gensim.models.keyedvectors.Vocab at 0x7f61365f2048>,
#  'كعب': <gensim.models.keyedvectors.Vocab at 0x7f61365f2080>,
#  'الأجهزة': <gensim.models.keyedvectors.Vocab at 0x7f61365f2f60>,
#  '(مصر)': <gensim.models.keyedvectors.Vocab at 0x7f61365f20b8>,
#  'مصرية': <gensim.models.keyedvectors.Vocab at 0x7f61365f20f0>,
#  'مصري': <gensim.models.keyedvectors.Vocab at 0x7f61365f2128>,
#  'انور': <gensim.models.keyedvectors.Vocab at 0x7f61365f2160>,
#  'قبطية': <gensim.models.keyedvectors.Vocab at 0x7f61365f21d0>,
#  'الاثني': <gensim.models.keyedvectors.Vocab at 0x7f61365f2208>,
#  'الخاصة': <gensim.models.keyedvectors.Vocab at 0x7f61365f2240>,
#  'خويلد': <gensim.models.keyedvectors.Vocab at 0x7f61365f2278>,
#  '(قبيلة)': <gensim.models.keyedvectors.Vocab at 0x7f61365f22b0>,
#  'حسنى': <gensim.models.keyedvectors.Vocab at 0x7f61365f22e8>,
#  'مهنا': <gensim.models.keyedvectors.Vocab at 0x7f61365f2358>,
#  'الشام': <gensim.models.keyedvectors.Vocab at 0x7f61365f2390>,
#  'كلثوم': <gensim.models.keyedvectors.Vocab at 0x7f61365f2400>,
#  'ثابت': <gensim.models.keyedvectors.Vocab at 0x7f61365f2438>,
#  'معالجة': <gensim.models.keyedvectors.Vocab at 0x7f61365f2470>,
#  'مركزية': <gensim.models.keyedvectors.Vocab at 0x7f61365f24a8>,
#  'الجديد': <gensim.models.keyedvectors.Vocab at 0x7f61365f25c0>,
#  'فلكية': <gensim.models.keyedvectors.Vocab at 0x7f61365f25f8>,
#  'عبدالوهاب': <gensim.models.keyedvectors.Vocab at 0x7f61365f2668>,
#  'ابي': <gensim.models.keyedvectors.Vocab at 0x7f61365f26a0>,
#  'طالب': <gensim.models.keyedvectors.Vocab at 0x7f61365f26d8>,
#  'أرثوذكسية': <gensim.models.keyedvectors.Vocab at 0x7f61365f2710>,
#  'كوشية': <gensim.models.keyedvectors.Vocab at 0x7f61365f2748>,
#  'الابيض': <gensim.models.keyedvectors.Vocab at 0x7f61365f2780>,
#  'كيميائية': <gensim.models.keyedvectors.Vocab at 0x7f61365f27b8>,
#  'المصرية': <gensim.models.keyedvectors.Vocab at 0x7f61365f28d0>,
#  'العبرية': <gensim.models.keyedvectors.Vocab at 0x7f61365f2940>,
#  'اليابانية': <gensim.models.keyedvectors.Vocab at 0x7f61365f2978>,
#  'إفريقيا': <gensim.models.keyedvectors.Vocab at 0x7f61365f2b38>,
#  'كونغولية': <gensim.models.keyedvectors.Vocab at 0x7f61365f2ba8>,
#  'نيجيرية': <gensim.models.keyedvectors.Vocab at 0x7f61365f2be0>,
#  'كونغولي': <gensim.models.keyedvectors.Vocab at 0x7f61365f2c50>,
#  'انجليزية': <gensim.models.keyedvectors.Vocab at 0x7f61365f2c88>,
#  'صوتية': <gensim.models.keyedvectors.Vocab at 0x7f61365f2cf8>,
#  'دولية': <gensim.models.keyedvectors.Vocab at 0x7f61365f29b0>,
#  'الصوتية': <gensim.models.keyedvectors.Vocab at 0x7f61365f2630>,
#  'الدولية': <gensim.models.keyedvectors.Vocab at 0x7f613f3da1d0>,
#  'الجن': <gensim.models.keyedvectors.Vocab at 0x7f613f3da208>,
#  'نحاسي': <gensim.models.keyedvectors.Vocab at 0x7f613f3da240>,
#  'المؤتمرات': <gensim.models.keyedvectors.Vocab at 0x7f613f3da048>,
#  'تشادية': <gensim.models.keyedvectors.Vocab at 0x7f613f3da080>,
#  'نيلية': <gensim.models.keyedvectors.Vocab at 0x7f613f3da0b8>,
#  '(لغات)': <gensim.models.keyedvectors.Vocab at 0x7f613f3da128>,
#  'قدماء': <gensim.models.keyedvectors.Vocab at 0x7f613f3da160>,
#  'ادارة': <gensim.models.keyedvectors.Vocab at 0x7f613f3da2b0>,
#  'المحتويات': <gensim.models.keyedvectors.Vocab at 0x7f613f3da2e8>,
#  '(انترنت)': <gensim.models.keyedvectors.Vocab at 0x7f613f3da320>,
#  'المصري': <gensim.models.keyedvectors.Vocab at 0x7f613f3da358>,
#  'البروج': <gensim.models.keyedvectors.Vocab at 0x7f613f3da0f0>,
#  'الايوبي': <gensim.models.keyedvectors.Vocab at 0x7f613f3da390>,
#  'فلكي': <gensim.models.keyedvectors.Vocab at 0x7f613f3da400>,
#  'سماوي': <gensim.models.keyedvectors.Vocab at 0x7f613f3da438>,
#  'سيار': <gensim.models.keyedvectors.Vocab at 0x7f613f3da470>,
#  'ابيض': <gensim.models.keyedvectors.Vocab at 0x7f613f3da4a8>,
#  'متوسط': <gensim.models.keyedvectors.Vocab at 0x7f613f3da4e0>,
#  'ال': <gensim.models.keyedvectors.Vocab at 0x7f613f3da518>,
#  'عناصر': <gensim.models.keyedvectors.Vocab at 0x7f613f3da550>,
#  'ن': <gensim.models.keyedvectors.Vocab at 0x7f613f3da780>,
#  'آي': <gensim.models.keyedvectors.Vocab at 0x7f613f3da7b8>,
#  'انفجار': <gensim.models.keyedvectors.Vocab at 0x7f613f3dada0>,
#  'عظيم': <gensim.models.keyedvectors.Vocab at 0x7f613f3dadd8>,
#  'عند': <gensim.models.keyedvectors.Vocab at 0x7f613f3dae10>,
#  'الأمازيغ': <gensim.models.keyedvectors.Vocab at 0x7f613f3dae48>,
#  'عتيقة': <gensim.models.keyedvectors.Vocab at 0x7f613f3dae80>,
#  'بالاس': <gensim.models.keyedvectors.Vocab at 0x7f613f3daeb8>,
#  'البحر': <gensim.models.keyedvectors.Vocab at 0x7f613f3daf28>,
#  'موسيقي': <gensim.models.keyedvectors.Vocab at 0x7f613f3da668>,
#  'جزر': <gensim.models.keyedvectors.Vocab at 0x7f613f3dafd0>,
#  'ريوكيو': <gensim.models.keyedvectors.Vocab at 0x7f6140c0f7b8>,
#  'فتوح': <gensim.models.keyedvectors.Vocab at 0x7f6140c0f898>,
#  'فارس': <gensim.models.keyedvectors.Vocab at 0x7f6140c0f978>,
#  'بنغالية': <gensim.models.keyedvectors.Vocab at 0x7f6140c0f9e8>,
#  'لال': <gensim.models.keyedvectors.Vocab at 0x7f6140c0fb00>,
#  'إستونية': <gensim.models.keyedvectors.Vocab at 0x7f6140c0fcf8>,
#  'ويكيبيديا': <gensim.models.keyedvectors.Vocab at 0x7f6140c0fe48>,
#  'الشيطان': <gensim.models.keyedvectors.Vocab at 0x7f6140c0feb8>,
#  'سوريا': <gensim.models.keyedvectors.Vocab at 0x7f6140c0ffd0>,
#  'حامد': <gensim.models.keyedvectors.Vocab at 0x7f6140c0f128>,
#  'الغزالي': <gensim.models.keyedvectors.Vocab at 0x7f6140c0f1d0>,
#  'السلطة': <gensim.models.keyedvectors.Vocab at 0x7f6140c0f208>,
#  'الغفران': <gensim.models.keyedvectors.Vocab at 0x7f6140c0f278>,
#  'لنا': <gensim.models.keyedvectors.Vocab at 0x7f6140c0f470>,
#  'جلالة': <gensim.models.keyedvectors.Vocab at 0x7f6140c0f588>,
#  'السلطان': <gensim.models.keyedvectors.Vocab at 0x7f6140c0f630>,
#  'بو': <gensim.models.keyedvectors.Vocab at 0x7f6140c0f748>,
#  'تساو': <gensim.models.keyedvectors.Vocab at 0x7f6140c0f780>,
#  '(إله)': <gensim.models.keyedvectors.Vocab at 0x7f613df52828>,
#  'آمون': <gensim.models.keyedvectors.Vocab at 0x7f613dbb4828>,
#  'الاسود': <gensim.models.keyedvectors.Vocab at 0x7f613dbb4eb8>,
#  'اسود': <gensim.models.keyedvectors.Vocab at 0x7f613dbb4b70>,
#  '(أسطورة)': <gensim.models.keyedvectors.Vocab at 0x7f613dbb44e0>,
#  'العلي': <gensim.models.keyedvectors.Vocab at 0x7f613dbb4780>,
#  'الأهلية': <gensim.models.keyedvectors.Vocab at 0x7f613dbb4208>,
#  'اللبنانية': <gensim.models.keyedvectors.Vocab at 0x7f613dbb4470>,
#  'الاهلية': <gensim.models.keyedvectors.Vocab at 0x7f613dbb4b38>,
#  'القدم': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe048>,
#  'دبليو': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe080>,
#  'إف': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe0b8>,
#  'القاسم': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe208>,
#  'الشابي': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe320>,
#  'أمازيغي': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe358>,
#  'قائمة': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe438>,
#  'ثانية': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe4a8>,
#  'وعشرون': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe4e0>,
#  'الهند': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe588>,
#  'العلاء': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe5f8>,
#  'المعري': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe6d8>,
#  '(القدس)': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe6a0>,
#  'إقبال': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe748>,
#  'كبير': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe860>,
#  'ثقيل': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe908>,
# ...
#  'Access': <gensim.models.keyedvectors.Vocab at 0x7f6140bfeda0>,
#  'memory': <gensim.models.keyedvectors.Vocab at 0x7f6140bfee10>,
#  'قصير': <gensim.models.keyedvectors.Vocab at 0x7f6140bfee48>,
#  'ثورية': <gensim.models.keyedvectors.Vocab at 0x7f6140bfeeb8>,
#  'فيثاغورس': <gensim.models.keyedvectors.Vocab at 0x7f6140bfeef0>,
#  'شعبي': <gensim.models.keyedvectors.Vocab at 0x7f6140bfef28>,
#  'أساسي': <gensim.models.keyedvectors.Vocab at 0x7f6140bfef98>,
#  'البخاري': <gensim.models.keyedvectors.Vocab at 0x7f6140bfe8d0>,
#  'الأساسية': <gensim.models.keyedvectors.Vocab at 0x7f6136393ac8>,
#  'الثورية': <gensim.models.keyedvectors.Vocab at 0x7f6136393b00>,
#  'الستة': <gensim.models.keyedvectors.Vocab at 0x7f61363936a0>,
#  'ايام': <gensim.models.keyedvectors.Vocab at 0x7f6136393ba8>,
#  'الخليج': <gensim.models.keyedvectors.Vocab at 0x7f6136393be0>,
#  'عظمى': <gensim.models.keyedvectors.Vocab at 0x7f6136393c18>,
#  'العاج': <gensim.models.keyedvectors.Vocab at 0x7f6136393c50>,
#  'إم': <gensim.models.keyedvectors.Vocab at 0x7f6136393c88>,
#  'الايام': <gensim.models.keyedvectors.Vocab at 0x7f6136393cc0>,
#  'الاسرائيلي': <gensim.models.keyedvectors.Vocab at 0x7f6136393cf8>,
#  'التحرير': <gensim.models.keyedvectors.Vocab at 0x7f6136393d30>,
#  'النبوي': <gensim.models.keyedvectors.Vocab at 0x7f6136393d68>,
#  'الأخضر': <gensim.models.keyedvectors.Vocab at 0x7f6136393da0>,
#  'شعبية': <gensim.models.keyedvectors.Vocab at 0x7f6136393dd8>,
#  '(نظام': <gensim.models.keyedvectors.Vocab at 0x7f6136393e10>,
#  'دو': <gensim.models.keyedvectors.Vocab at 0x7f6136393e48>,
#  'زين': <gensim.models.keyedvectors.Vocab at 0x7f6136393ef0>,
#  'والمعراج': <gensim.models.keyedvectors.Vocab at 0x7f6136393f60>,
#  'أورالية': <gensim.models.keyedvectors.Vocab at 0x7f6136393f98>,
#  'الرازي': <gensim.models.keyedvectors.Vocab at 0x7f6136393fd0>,
#  'تحليلية': <gensim.models.keyedvectors.Vocab at 0x7f6136393828>,
#  'التحليلية': <gensim.models.keyedvectors.Vocab at 0x7f6136393048>,
#  'القرضابية': <gensim.models.keyedvectors.Vocab at 0x7f6136393080>,
#  'براون': <gensim.models.keyedvectors.Vocab at 0x7f61363930b8>,
#  'رومنسية': <gensim.models.keyedvectors.Vocab at 0x7f61363930f0>,
#  'بومدين': <gensim.models.keyedvectors.Vocab at 0x7f6136393128>,
#  'عدد': <gensim.models.keyedvectors.Vocab at 0x7f6136393160>,
#  'الأصليين': <gensim.models.keyedvectors.Vocab at 0x7f6136393198>,
#  'عباس': <gensim.models.keyedvectors.Vocab at 0x7f61363931d0>,
#  'البرغوثي': <gensim.models.keyedvectors.Vocab at 0x7f6136393208>,
#  'الدرة': <gensim.models.keyedvectors.Vocab at 0x7f6136393240>,
#  'زيت': <gensim.models.keyedvectors.Vocab at 0x7f6136393278>,
#  'سني': <gensim.models.keyedvectors.Vocab at 0x7f61363932b0>,
#  'بيرزيت': <gensim.models.keyedvectors.Vocab at 0x7f61363932e8>,
#  'صلب': <gensim.models.keyedvectors.Vocab at 0x7f6136393320>,
#  'سرت': <gensim.models.keyedvectors.Vocab at 0x7f6136393400>,
#  'معد': <gensim.models.keyedvectors.Vocab at 0x7f6136393438>,
#  'والفيزياء': <gensim.models.keyedvectors.Vocab at 0x7f6136393470>,
#  'الفلكية': <gensim.models.keyedvectors.Vocab at 0x7f61363934e0>,
#  'حاسبات': <gensim.models.keyedvectors.Vocab at 0x7f6136393518>,
#  'الدوري': <gensim.models.keyedvectors.Vocab at 0x7f6136393588>,
#  'الاندلس': <gensim.models.keyedvectors.Vocab at 0x7f61363935c0>,
#  'الانفجار': <gensim.models.keyedvectors.Vocab at 0x7f6136393630>,
#  'الاردنية': <gensim.models.keyedvectors.Vocab at 0x7f6136393668>,
#  'اعلام': <gensim.models.keyedvectors.Vocab at 0x7f61363936d8>,
#  'امون': <gensim.models.keyedvectors.Vocab at 0x7f6136393710>,
#  'الاساسية': <gensim.models.keyedvectors.Vocab at 0x7f6136393748>,
#  'علوية': <gensim.models.keyedvectors.Vocab at 0x7f61363937b8>,
#  'الاعلامية': <gensim.models.keyedvectors.Vocab at 0x7f61363937f0>,
#  'للشرق': <gensim.models.keyedvectors.Vocab at 0x7f6136393860>,
#  'السنة': <gensim.models.keyedvectors.Vocab at 0x7f6136393898>,
#  'الجماعة': <gensim.models.keyedvectors.Vocab at 0x7f61363938d0>,
#  'الاخضر': <gensim.models.keyedvectors.Vocab at 0x7f6136393908>,
#  'عشر': <gensim.models.keyedvectors.Vocab at 0x7f6136393940>,
#  'تاكا': <gensim.models.keyedvectors.Vocab at 0x7f6136393978>,
#  'الاتحاد': <gensim.models.keyedvectors.Vocab at 0x7f61363939b0>,
#  '(كتابة)': <gensim.models.keyedvectors.Vocab at 0x7f61363939e8>,
#  'الابراهيمي': <gensim.models.keyedvectors.Vocab at 0x7f6136393a20>,
#  'الاحمر': <gensim.models.keyedvectors.Vocab at 0x7f6136393a58>,
#  'عشرون': <gensim.models.keyedvectors.Vocab at 0x7f6136393a90>,
#  'انترنت': <gensim.models.keyedvectors.Vocab at 0x7f61368822e8>,
#  'الاطلسي': <gensim.models.keyedvectors.Vocab at 0x7f6136882358>,
#  '(اسلام)': <gensim.models.keyedvectors.Vocab at 0x7f6136882390>,
#  'الهندي': <gensim.models.keyedvectors.Vocab at 0x7f61368823c8>,
#  'دينس': <gensim.models.keyedvectors.Vocab at 0x7f6136882400>,
#  'روهان': <gensim.models.keyedvectors.Vocab at 0x7f6136882438>,
#  'أكبر': <gensim.models.keyedvectors.Vocab at 0x7f6136882470>,
#  '(نشيد)': <gensim.models.keyedvectors.Vocab at 0x7f61368824a8>,
#  'كلاسيكية': <gensim.models.keyedvectors.Vocab at 0x7f61368824e0>,
#  '(مسلسل)': <gensim.models.keyedvectors.Vocab at 0x7f6136882518>,
#  'سكريبت': <gensim.models.keyedvectors.Vocab at 0x7f6136882550>,
#  'فلاحي': <gensim.models.keyedvectors.Vocab at 0x7f61368825c0>,
#  'مغربي': <gensim.models.keyedvectors.Vocab at 0x7f61368825f8>,
#  'ك.': <gensim.models.keyedvectors.Vocab at 0x7f6136882668>,
#  '1948': <gensim.models.keyedvectors.Vocab at 0x7f61368826a0>,
#  '(مرض)': <gensim.models.keyedvectors.Vocab at 0x7f61368826d8>,
#  'أحداث': <gensim.models.keyedvectors.Vocab at 0x7f6136882710>,
#  'حرب': <gensim.models.keyedvectors.Vocab at 0x7f6136882748>,
#  'دالت': <gensim.models.keyedvectors.Vocab at 0x7f6136882780>,
#  'يارفا': <gensim.models.keyedvectors.Vocab at 0x7f61368827b8>,
#  'حمورابي': <gensim.models.keyedvectors.Vocab at 0x7f61368827f0>,
#  'تجارية': <gensim.models.keyedvectors.Vocab at 0x7f6136882828>,
#  'ويلزية': <gensim.models.keyedvectors.Vocab at 0x7f6136882898>,
#  '(محافظة)': <gensim.models.keyedvectors.Vocab at 0x7f61368828d0>,
#  'سعودية': <gensim.models.keyedvectors.Vocab at 0x7f6136882940>,
#  'الصديق': <gensim.models.keyedvectors.Vocab at 0x7f61368829b0>,
#  'مسلمون': <gensim.models.keyedvectors.Vocab at 0x7f6136882a90>,
#  'شارون': <gensim.models.keyedvectors.Vocab at 0x7f6136882dd8>,
#  'الاسلام': <gensim.models.keyedvectors.Vocab at 0x7f6136882e10>,
#  'غلوب': <gensim.models.keyedvectors.Vocab at 0x7f6136882e80>,
#  'صينية': <gensim.models.keyedvectors.Vocab at 0x7f6136882eb8>,
#  'وتسونامي': <gensim.models.keyedvectors.Vocab at 0x7f6136882ef0>,
#  'المحيط': <gensim.models.keyedvectors.Vocab at 0x7f6136882f28>,
#  'قزمان': <gensim.models.keyedvectors.Vocab at 0x7f6136882f60>,
#  'جامعة': <gensim.models.keyedvectors.Vocab at 0x7f6136882f98>,
#  'العام': <gensim.models.keyedvectors.Vocab at 0x7f6136882fd0>,
#  'لجامعة': <gensim.models.keyedvectors.Vocab at 0x7f6136882048>,
#  'تاريخية': <gensim.models.keyedvectors.Vocab at 0x7f6136882128>,
#  'ميازاكي': <gensim.models.keyedvectors.Vocab at 0x7f6136882198>,
#  'اولى': <gensim.models.keyedvectors.Vocab at 0x7f6136882160>,
#  'حماه': <gensim.models.keyedvectors.Vocab at 0x7f61368821d0>,
#  'اولمبية': <gensim.models.keyedvectors.Vocab at 0x7f6136882208>,
#  'الاولى': <gensim.models.keyedvectors.Vocab at 0x7f6136882ba8>,
#  'تجميع': <gensim.models.keyedvectors.Vocab at 0x7f6136882278>,
#  'غربية': <gensim.models.keyedvectors.Vocab at 0x7f61368822b0>,
#  'السعودية': <gensim.models.keyedvectors.Vocab at 0x7f613f372a20>,
#  'اسرائيل': <gensim.models.keyedvectors.Vocab at 0x7f613f372a58>,
#  'اهلية': <gensim.models.keyedvectors.Vocab at 0x7f613f372a90>,
#  'لبنانية': <gensim.models.keyedvectors.Vocab at 0x7f613f372ac8>,
#  'اسرائيلي': <gensim.models.keyedvectors.Vocab at 0x7f613f372b00>,
#  'اكتوبر': <gensim.models.keyedvectors.Vocab at 0x7f613f372b38>,
#  'شعب': <gensim.models.keyedvectors.Vocab at 0x7f613f372b70>,
#  'فلسطيني': <gensim.models.keyedvectors.Vocab at 0x7f613f372ba8>,
#  'اسلامية': <gensim.models.keyedvectors.Vocab at 0x7f613f372be0>,
#  'دولي': <gensim.models.keyedvectors.Vocab at 0x7f613f372cc0>,
#  'ان': <gensim.models.keyedvectors.Vocab at 0x7f613f372278>,
#  'او': <gensim.models.keyedvectors.Vocab at 0x7f613f3722e8>,
#  'اس': <gensim.models.keyedvectors.Vocab at 0x7f613f372320>,
#  'عبدالله': <gensim.models.keyedvectors.Vocab at 0x7f613f372390>,
#  'عبدالعزيز': <gensim.models.keyedvectors.Vocab at 0x7f613f372048>,
#  'الانترنت': <gensim.models.keyedvectors.Vocab at 0x7f613f372400>,
#  'اكس': <gensim.models.keyedvectors.Vocab at 0x7f613f372438>,
#  'اتحاد': <gensim.models.keyedvectors.Vocab at 0x7f613f3724e0>,
#  'اقبال': <gensim.models.keyedvectors.Vocab at 0x7f613f372518>,
#  'كمال': <gensim.models.keyedvectors.Vocab at 0x7f613f372550>,
#  'وطني': <gensim.models.keyedvectors.Vocab at 0x7f613f372588>,
#  'الاردن': <gensim.models.keyedvectors.Vocab at 0x7f613f3725c0>,
#  '(قمر)': <gensim.models.keyedvectors.Vocab at 0x7f613f3725f8>,
#  'شرابي': <gensim.models.keyedvectors.Vocab at 0x7f613f372630>,
#  'طبيعية': <gensim.models.keyedvectors.Vocab at 0x7f613f372668>,
#  'متولي': <gensim.models.keyedvectors.Vocab at 0x7f613f3726a0>,
#  'الشعراوي': <gensim.models.keyedvectors.Vocab at 0x7f613f3726d8>,
#  'الدفلى': <gensim.models.keyedvectors.Vocab at 0x7f613f372710>,
#  'حرارة': <gensim.models.keyedvectors.Vocab at 0x7f613f372748>,
#  'مئوية': <gensim.models.keyedvectors.Vocab at 0x7f613f372780>,
#  'السلة': <gensim.models.keyedvectors.Vocab at 0x7f613f3727f0>,
#  'شكسبير': <gensim.models.keyedvectors.Vocab at 0x7f613f372828>,
#  'صينيون': <gensim.models.keyedvectors.Vocab at 0x7f613f372860>,
#  'أردن': <gensim.models.keyedvectors.Vocab at 0x7f613f3728d0>,
#  'تصويت': <gensim.models.keyedvectors.Vocab at 0x7f613f372940>,
#  'للحذف': <gensim.models.keyedvectors.Vocab at 0x7f613f3729b0>,
#  'ليبيا': <gensim.models.keyedvectors.Vocab at 0x7f613f3729e8>,
#  'العامة': <gensim.models.keyedvectors.Vocab at 0x7f613f372cf8>,
#  'وطنية': <gensim.models.keyedvectors.Vocab at 0x7f613f372d30>,
#  'أوروبا': <gensim.models.keyedvectors.Vocab at 0x7f613f372d68>,
#  'العالم': <gensim.models.keyedvectors.Vocab at 0x7f613f372da0>,
#  'ياباني': <gensim.models.keyedvectors.Vocab at 0x7f613f372dd8>,
#  'السودان': <gensim.models.keyedvectors.Vocab at 0x7f613f372e10>,
#  'الدردشة': <gensim.models.keyedvectors.Vocab at 0x7f613f372e48>,
#  'الاسلامي': <gensim.models.keyedvectors.Vocab at 0x7f613f372e80>,
#  'القبائل': <gensim.models.keyedvectors.Vocab at 0x7f613f372eb8>,
#  'بوش': <gensim.models.keyedvectors.Vocab at 0x7f613f372ef0>,
#  'غاليلي': <gensim.models.keyedvectors.Vocab at 0x7f613f372f28>,
#  'بريسلي': <gensim.models.keyedvectors.Vocab at 0x7f613f372f60>,
#  'سعودي': <gensim.models.keyedvectors.Vocab at 0x7f613f372f98>,
#  'طوقان': <gensim.models.keyedvectors.Vocab at 0x7f613f372fd0>,
#  'ليبيري': <gensim.models.keyedvectors.Vocab at 0x7f613f3723c8>,
#  'نيكسون': <gensim.models.keyedvectors.Vocab at 0x7f613f372080>,
#  'الكتاب': <gensim.models.keyedvectors.Vocab at 0x7f613f3720b8>,
#  'كلينتون': <gensim.models.keyedvectors.Vocab at 0x7f613f3720f0>,
#  'غورباتشوف': <gensim.models.keyedvectors.Vocab at 0x7f613f372160>,
#  'كولمبوس': <gensim.models.keyedvectors.Vocab at 0x7f613f372208>,
#  'صدام': <gensim.models.keyedvectors.Vocab at 0x7f613f372240>,
#  'حسين': <gensim.models.keyedvectors.Vocab at 0x7f61368655f8>,
#  'شيراك': <gensim.models.keyedvectors.Vocab at 0x7f6136865630>,
#  'الام': <gensim.models.keyedvectors.Vocab at 0x7f6136865668>,
#  'جوي': <gensim.models.keyedvectors.Vocab at 0x7f61368656a0>,
#  'كنفاني': <gensim.models.keyedvectors.Vocab at 0x7f61368656d8>,
#  'أنان': <gensim.models.keyedvectors.Vocab at 0x7f6136865710>,
#  'جيفارا': <gensim.models.keyedvectors.Vocab at 0x7f6136865748>,
#  'كشف': <gensim.models.keyedvectors.Vocab at 0x7f6136865780>,
#  'الكذب': <gensim.models.keyedvectors.Vocab at 0x7f61368657b8>,
#  'ضوئية': <gensim.models.keyedvectors.Vocab at 0x7f61368657f0>,
#  'دولة': <gensim.models.keyedvectors.Vocab at 0x7f6136865828>,
#  'الرسول': <gensim.models.keyedvectors.Vocab at 0x7f6136865860>,
#  'تاريخ': <gensim.models.keyedvectors.Vocab at 0x7f6136865898>,
#  'علوم': <gensim.models.keyedvectors.Vocab at 0x7f61368658d0>,
#  'دا': <gensim.models.keyedvectors.Vocab at 0x7f6136865908>,
#  'فينشي': <gensim.models.keyedvectors.Vocab at 0x7f6136865940>,
#  'كذب': <gensim.models.keyedvectors.Vocab at 0x7f6136865978>,
#  'حكومة': <gensim.models.keyedvectors.Vocab at 0x7f61368659b0>,
#  'من': <gensim.models.keyedvectors.Vocab at 0x7f61368659e8>,
#  'جغرافيا': <gensim.models.keyedvectors.Vocab at 0x7f6136865a58>,
#  'السوفييت': <gensim.models.keyedvectors.Vocab at 0x7f6136865a90>,
#  'الأعلى': <gensim.models.keyedvectors.Vocab at 0x7f6136865ac8>,
#  'ابراهيم': <gensim.models.keyedvectors.Vocab at 0x7f6136865b00>,
#  'باسكال': <gensim.models.keyedvectors.Vocab at 0x7f6136865b38>,
#  'رياضيون': <gensim.models.keyedvectors.Vocab at 0x7f6136865b70>,
#  'أفارقة': <gensim.models.keyedvectors.Vocab at 0x7f6136865ba8>,
#  'أفريقيون': <gensim.models.keyedvectors.Vocab at 0x7f6136865be0>,
#  'أفريقيا': <gensim.models.keyedvectors.Vocab at 0x7f6136865c18>,
#  'وزارة': <gensim.models.keyedvectors.Vocab at 0x7f6136865c50>,
#  'بريطانيا': <gensim.models.keyedvectors.Vocab at 0x7f6136865c88>,
#  '(لوحة)': <gensim.models.keyedvectors.Vocab at 0x7f6136865cc0>,
#  'أبي': <gensim.models.keyedvectors.Vocab at 0x7f6136865cf8>,
#  'جمهورية': <gensim.models.keyedvectors.Vocab at 0x7f6136865a20>,
#  'تركيا': <gensim.models.keyedvectors.Vocab at 0x7f6136865d30>,
#  'الشمالية': <gensim.models.keyedvectors.Vocab at 0x7f6136865d68>,
#  '2005': <gensim.models.keyedvectors.Vocab at 0x7f6136865da0>,
#  'التأين': <gensim.models.keyedvectors.Vocab at 0x7f6136865e10>,
#  'الإنسان': <gensim.models.keyedvectors.Vocab at 0x7f6136865e80>,
#  'المدن': <gensim.models.keyedvectors.Vocab at 0x7f6136865eb8>,
#  'المغاربية': <gensim.models.keyedvectors.Vocab at 0x7f6136865ef0>,
#  'الفينيقية': <gensim.models.keyedvectors.Vocab at 0x7f6136865f28>,
#  'تيارت': <gensim.models.keyedvectors.Vocab at 0x7f6136865f60>,
#  'تموشنت': <gensim.models.keyedvectors.Vocab at 0x7f6136865f98>,
#  '(شمال': <gensim.models.keyedvectors.Vocab at 0x7f6136865fd0>,
#  'أفريقيا)': <gensim.models.keyedvectors.Vocab at 0x7f6136865048>,
#  'متباعدة': <gensim.models.keyedvectors.Vocab at 0x7f6136865080>,
#  'الصوت': <gensim.models.keyedvectors.Vocab at 0x7f61368650b8>,
#  'إدلب': <gensim.models.keyedvectors.Vocab at 0x7f61368650f0>,
#  'أوكرانيا': <gensim.models.keyedvectors.Vocab at 0x7f6136865160>,
#  'ويب': <gensim.models.keyedvectors.Vocab at 0x7f6136865198>,
#  'اللجان': <gensim.models.keyedvectors.Vocab at 0x7f61368651d0>,
#  'بل': <gensim.models.keyedvectors.Vocab at 0x7f6136865208>,
#  'الأول': <gensim.models.keyedvectors.Vocab at 0x7f6136865240>,
#  '(إمبراطور)': <gensim.models.keyedvectors.Vocab at 0x7f61368652b0>,
#  'بوليفار': <gensim.models.keyedvectors.Vocab at 0x7f61368652e8>,
#  'فاراداي': <gensim.models.keyedvectors.Vocab at 0x7f6136865320>,
#  'ماركوني': <gensim.models.keyedvectors.Vocab at 0x7f6136865358>,
#  'إديسون': <gensim.models.keyedvectors.Vocab at 0x7f61368653c8>,
#  'وات': <gensim.models.keyedvectors.Vocab at 0x7f6136865400>,
#  'لكرة': <gensim.models.keyedvectors.Vocab at 0x7f6136865438>,
#  'كأس': <gensim.models.keyedvectors.Vocab at 0x7f6136865470>,
#  '2002': <gensim.models.keyedvectors.Vocab at 0x7f61368654a8>,
#  'عمل': <gensim.models.keyedvectors.Vocab at 0x7f6136865518>,
#  'التعليم': <gensim.models.keyedvectors.Vocab at 0x7f6136865588>,
#  'القديمة': <gensim.models.keyedvectors.Vocab at 0x7f61368655c0>,
#  'السيستاني': <gensim.models.keyedvectors.Vocab at 0x7f6135a03048>,
#  'الإسلامية': <gensim.models.keyedvectors.Vocab at 0x7f6135a03080>,
#  'للإنقاذ': <gensim.models.keyedvectors.Vocab at 0x7f6135a030b8>,
#  'الجزائرية': <gensim.models.keyedvectors.Vocab at 0x7f6135a030f0>,
#  'آلي': <gensim.models.keyedvectors.Vocab at 0x7f6135a03128>,
#  'الي': <gensim.models.keyedvectors.Vocab at 0x7f6135a03160>,
#  'الآلي': <gensim.models.keyedvectors.Vocab at 0x7f6135a03198>,
#  'شخصي': <gensim.models.keyedvectors.Vocab at 0x7f6135a031d0>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x7f6135a03208>,
#  'الصلبة': <gensim.models.keyedvectors.Vocab at 0x7f6135a03240>,
#  'كرة': <gensim.models.keyedvectors.Vocab at 0x7f6135a03278>,
#  ...}

# %%
# عرض مثال للكلمات المترادفة لكلمة انسان  كما لو كانت كلمة الله هي المراد البحث عنها في الويكي بديا 
#  النتائج تخضع للوثائق التي تم تدريبها في هذا النموزج وليست ثابته 
def synset_W2V(word):
    synset_W2V=ar_model.wv.most_similar(word)
    return synset_W2V

syns_w2v=synset_W2V('الله')
syns_w2v
# Out:
# [('الرحمن', 0.8728058338165283),
#  ('القادر', 0.85809326171875),
#  ('الكريم', 0.8560231924057007),
#  ('الحميد', 0.8522861003875732),
#  ('الرحيم', 0.8483253717422485),
#  ('اللطيف', 0.8436490297317505),
#  ('الوهاب', 0.8368901014328003),
#  ('الرزاق', 0.8240257501602173),
#  ('المجيد', 0.8220633864402771),
#  ('السلام', 0.8179967403411865)]

# %% [markdown]
# ## الحصول علي المرادفات من الورد نت
# الوردنت كقاموس معجمي تظهر فيهالنتائج ثابتة في كل مرة او بتحدث بيناتة
# يقسم الورد نت الكلمات والعلاقات فيما بينها لعلاقة
# is-a,has-a,part-of.....etc
# ويوجد علاقات شجرية بين الكلمات
# يعتمد علي الورد نت في التحليل الدلالي للكلمات وايجاد العلاقات الدلالية الحقيقية فيما بينها

# %%
import nltk
from nltk.corpus import wordnet as wn

#nltk.download('omw')
def synset_wordnet(word,lang):
    return wn.synsets(word, lang=lang)

       

def lema_name(syn,lang):
    return syn.lemma_names(lang)

# %%
#مرادفات كلمة الله في الورد نت باللغة الانجليزية
syns=synset_wordnet('الله',"arb")
syns
# Out:
# [Synset('deity.n.01'), Synset('allah.n.01')]

# %%
lema_name(syns[0],'arb')
# مرادفات الكلمة الاولي باللغة العربية Synset('deity.n.01')
# Out:
# ['الخالِق', 'الرَّبّ', 'الله', 'المعْبُود', 'الواجِد', 'الواحِد']

# %%
lema_name(syns[1],'arb')
# مرادفات الكلمة التانية باللغة العربية  Synset('allah.n.01')
# Out:
# ['الله', 'اللَه']

# %%
#اذن يمكنا البحث في الويكي بديا عن كلمة الله وعن
#الخالِق', 'الرَّبّ', 'الله', 'المعْبُود', 'الواجِد', 'الواحِد','الرحمن','الكريم','القادر','الحميد','الرحيم', 'النبي','الوهاب','المجيد', 'الرزاق', 'الغني'
def syns_w2v_list(syns_w2v):
    w2v_word=[]
    i=0
    for w in syns_w2v:
        w2v_word.append(syns_w2v[i][0])
        i +=1
    return w2v_word
    
syns_w2v_list(syns_w2v)
# Out:
# ['الرحمن',
#  'القادر',
#  'الكريم',
#  'الحميد',
#  'الرحيم',
#  'اللطيف',
#  'الوهاب',
#  'الرزاق',
#  'المجيد',
#  'السلام']

# %%
def syns_wordnet_list(syns,lang):
    
    wordnet_word=[]
    i=0
    for syn in syns:
        lema_names=lema_name(syns[i],lang)
        for name in lema_names:
            
            wordnet_word.append(name)
        i +=1
    return wordnet_word

syns_wordnet_list(syns,'arb')
# Out:
# ['الخالِق',
#  'الرَّبّ',
#  'الله',
#  'المعْبُود',
#  'الواجِد',
#  'الواحِد',
#  'الله',
#  'اللَه']

# %%
# البحث في الويكي بديا 
#https://pypi.org/project/Wikipedia-API/0.3.5/

# %%
import wikipediaapi

# %%
def wikiperdia_text(word,lang):
    
    wiki_wiki = wikipediaapi.Wikipedia(
            language=lang,
            extract_format=wikipediaapi.ExtractFormat.WIKI
    )

    p_wiki = wiki_wiki.page(word)
    return p_wiki.text

wikiperdia_text("الله",'en')
# Out:
# 'Allah (; Arabic: الله\u200e, translit. Allāh, IPA: [ɑɫˈɫɑː(h)] ( listen)) is the Arabic word for God in Abrahamic religions. In the English language, the word generally refers to God in Islam. The word is thought to be derived by contraction from al-ilāh, which means "the god", and is related to El and Elah, the Hebrew and Aramaic words for God.\nThe word Allah has been used by Arabic people of different religions since pre-Islamic times. More specifically, it has been used as a term for God by Muslims (both Arab and non-Arab) and Arab Christians. It is also often, albeit not exclusively, used in this way by Bábists, Bahá\'ís, Mandaeans, Indonesian and Maltese Christians, and Mizrahi Jews. Similar usage by Christians and Sikhs in West Malaysia has recently led to political and legal controversies.\n\nEtymology\nThe etymology of the word Allāh has been discussed extensively by classical Arab philologists. Grammarians of the Basra school regarded it as either formed "spontaneously" (murtajal) or as the definite form of lāh (from the verbal root lyh with the meaning of "lofty" or "hidden"). Others held that it was borrowed from Syriac or Hebrew, but most considered it to be derived from a contraction of the Arabic definite article al- "the" and ilāh "deity, god" to al-lāh meaning "the deity", or "the God". The majority of modern scholars subscribe to the latter theory, and view the loanword hypothesis with skepticism.\nCognates of the name "Allāh" exist in other Semitic languages, including Hebrew and Aramaic. The corresponding Aramaic form is Elah (אלה), but its emphatic state is Elaha (אלהא). It is written as ܐܠܗܐ (ʼĔlāhā) in Biblical Aramaic and ܐܲܠܵܗܵܐ (ʼAlâhâ) in Syriac as used by the Assyrian Church, both meaning simply "God". Biblical Hebrew mostly uses the plural (but functional singular) form Elohim (אלהים\u202c), but more rarely it also uses the singular form Eloah (אלוהּ\u202c).\n\nUsage\nPre-Islamic Arabians\nRegional variants of the word Allah occur in both pagan and Christian pre-Islamic inscriptions. Different theories have been proposed regarding the role of Allah in pre-Islamic polytheistic cults. Some authors have suggested that polytheistic Arabs used the name as a reference to a creator god or a supreme deity of their pantheon. The term may have been vague in the Meccan religion. According to one hypothesis, which goes back to Julius Wellhausen, Allah (the supreme deity of the tribal federation around Quraysh) was a designation that consecrated the superiority of Hubal (the supreme deity of Quraysh) over the other gods. However, there is also evidence that Allah and Hubal were two distinct deities. According to that hypothesis, the Kaaba was first consecrated to a supreme deity named Allah and then hosted the pantheon of Quraysh after their conquest of Mecca, about a century before the time of Muhammad. Some inscriptions seem to indicate the use of Allah as a name of a polytheist deity centuries earlier, but we know nothing precise about this use. Some scholars have suggested that Allah may have represented a remote creator god who was gradually eclipsed by more particularized local deities. There is disagreement on whether Allah played a major role in the Meccan religious cult. No iconic representation of Allah is known to have existed. Muhammad\'s father\'s name was ʿAbd-Allāh meaning "the slave of Allāh".\n\nChristianity\nThe Aramaic word for "God" in the language of Assyrian Christians is ʼĔlāhā, or Alaha. Arabic-speakers of all Abrahamic faiths, including Christians and Jews, use the word "Allah" to mean "God". The Christian Arabs of today have no other word for "God" than "Allah". (Even the Arabic-descended Maltese language of Malta, whose population is almost entirely Roman Catholic, uses Alla for "God".) Arab Christians, for example, use the terms Allāh al-ab (الله الأب) for God the Father, Allāh al-ibn (الله الابن) for God the Son, and Allāh al-rūḥ al-quds (الله الروح القدس) for God the Holy Spirit.  ...
